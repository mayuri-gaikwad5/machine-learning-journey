# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\2309m\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\2309m\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\2309m\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\2309m\anaconda3\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\2309m\anaconda3\lib\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: colorama in c:\users\2309m\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
corpus=""" 
Hello Welcome , to John's NLP Tutorials.
Please do watch the entire couse! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
#
# Hello Welcome , to John's NLP Tutorials.
# Please do watch the entire couse! to become expert in NLP.

# %%
# Tokenization 
# sentence---> paragraphs

from nltk.tokenize import sent_tokenize

# %%
sent_tokenize(corpus)
# Out:
# [" \nHello Welcome , to John's NLP Tutorials.",
#  'Please do watch the entire couse!',
#  'to become expert in NLP.']

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
#
# Hello Welcome , to John's NLP Tutorials.
# Please do watch the entire couse!
# to become expert in NLP.

# %%
## Tokenization
## paragraph---->words
## sentence---> words

from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'John',
#  "'s",
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'couse',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'John', "'s", 'NLP', 'Tutorials', '.']
# ['Please', 'do', 'watch', 'the', 'entire', 'couse', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'John',
#  "'",
#  's',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'couse',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'John',
#  "'s",
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'couse',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
